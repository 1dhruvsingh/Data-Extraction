# %%
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
world =gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
# Out:
# <ipython-input-2-b457acf28c52>:1: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world =gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
world['scaled']=world['pop_est']/10**6

# %%
world.plot(figsize=(10,10),column='scaled',legend=True)
# Out:
# <Axes: >

# %%
plt.title('cartogram of the world')
plt.show()

# %%
import folium

# %%
from folium.plugins import HeatMap

# %%
m=folium.Map(location=[45.5236, -122.6750],zoom_start=5)
data = [
    [45.5236, -122.6750],
    [45.5236, -122.6750],
    [45.5236, -122.6750],
    [45.5236, -122.6750]
]

# %%
HeatMap(data).add_to(m)
m.save('heatmap.html')

# %%
import matplotlib.pyplot as plt
labels=['A','B','C','D']
sizes=[20,30,40,10]

fig, ax=plt.subplots()
wedges, texts ,autotexts=ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140, wedgesprops=dict(width=0.3))

centre_cicle = plt.Circle((0,0),0.2 ,color= 'white', fc='white')
fig.gca().add_artist(centre_cicle)

ax.axis('equal')
plt.title('Ring Chart')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-6cc228206023> in <cell line: 6>()
#       4
#       5 fig, ax=plt.subplots()
# ----> 6 wedges, texts ,autotexts=ax.pie(sizes, labels=labels, autopct='%1.1f%%', startangle=140, wedgesprops=dict(width=0.3))
#       7
#       8 centre_cicle = plt.Circle((0,0),0.2 ,color= 'white', fc='white')
#
# /usr/local/lib/python3.10/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1440     def inner(ax, *args, data=None, **kwargs):
#    1441         if data is None:
# -> 1442             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1443
#    1444         bound = new_sig.bind(ax, *args, **kwargs)
#
# TypeError: Axes.pie() got an unexpected keyword argument 'wedgesprops'

# %%
import plotly.graph_objects as go

lables=['root','A','B','A1','A2','B1']
parents = ['','root','root','A','A','B']

fig= go.Figure(go.Sunburst(
    labels=labels,
    parents=parents,
    values=[10,20,30,10,10,10]
))
fig.update_layout(margin=dict(t=0,l=0,r=0,b=0))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import matplotlib.pyplot as plt
import networkx as nx

# %%
G = nx.DiGraph()
edges= [('Root','A'),('Root','B'),('A','A1'),('A','A2'),('B','B1')]
G.add_edges_from(edges)
pos= nx.spring_layout(G,seed=42)
plt.figure(figsize=(10,10))
nx.draw(G,pos,with_labels=True,arrows=True,node_size=2000,node_color='skyblue',font_size=10,font_weight='bold')
plt.title('tree diagram')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
np.random.seed(0)
data1= np.random.normal(0,1,1000)
data2= np.random.normal(0,1.5,1000)

plt.figure(figsize=(10,6))
plt.hist(data1,bins=30, alpha=0.5, label='data1')
plt.hist(data2,bins=30, alpha=0.5, label='data2')
plt.title('Multiple Histograms')
plt.xlabel('Value')2
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
labels = ['Category A', 'Category B', 'Category C']
sizes = [20, 35, 45]

plt.figure(figsize=(7, 7))
plt.pie(sizes, labels=labels,autopct='%1.1f%%', startangle=140)
plt.title('Pie Chart')
plt.show()
