# %%
import pandas as pd

# %%
ozone_mean=air['Ozone'].mean()
print("Mean of ozone",ozone_mean)
ozone_mode=air['Ozone'].mode()
print(ozone_mode)
# Out:
# Mean of ozone 42.12931034482759
# 0    23.0
# Name: Ozone, dtype: float64

# %%
file_path= 'airquality.csv'
air=pd.read_csv(file_path)
print(air.head())
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0           1   41.0    190.0   7.4    67      5    1
# 1           2   36.0    118.0   8.0    72      5    2
# 2           3   12.0    149.0  12.6    74      5    3
# 3           4   18.0    313.0  11.5    62      5    4
# 4           5    NaN      NaN  14.3    56      5    5

# %%
ozone_std=air['Ozone'].std()
print(ozone_std)
# Out:
# 32.98788451443395

# %%
ozone_max=air['Ozone'].max()
print(ozone_max)
# Out:
# 168.0

# %%
ozone_min=air['Ozone'].min()
print(ozone_min)
# Out:
# 1.0

# %%
ozone_median=air['Ozone'].median()
print(ozone_median)
# Out:
# 31.5

# %%
solar_std=air['Solar.R'].std()
print(solar_std)
# Out:
# 90.05842222838167

# %%
solar_median=air['Solar.R'].median()
print(solar_median)
# Out:
# 205.0

# %%
solar_min=air['Solar.R'].min()
print(solar_min)
# Out:
# 7.0

# %%
solar_max=air['Solar.R'].max()
print(solar_max)
# Out:
# 334.0

# %%
na_values=air.isnull().sum()
print(na_values)
air_cleaned=air.dropna(subset=['Ozone'])
na_values_cleaned=air_cleaned.isnull().sum()
print(na_values_cleaned)
# Out:
# Unnamed: 0     0
# Ozone         37
# Solar.R        7
# Wind           0
# Temp           0
# Month          0
# Day            0
# dtype: int64
# Unnamed: 0    0
# Ozone         0
# Solar.R       5
# Wind          0
# Temp          0
# Month         0
# Day           0
# dtype: int64

# %%
print(air.head())
ozone_mode=air['Solar.R'].mode()[0]
air['Solar.R'].fillna(ozone_mode,inplace=True)
print(air['Solar.R'].isnull().sum())
print(air.head())
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0           1   41.0    190.0   7.4    67      5    1
# 1           2   36.0    118.0   8.0    72      5    2
# 2           3   12.0    149.0  12.6    74      5    3
# 3           4   18.0    313.0  11.5    62      5    4
# 4           5    NaN      NaN  14.3    56      5    5
# 0
#    Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0           1   41.0    190.0   7.4    67      5    1
# 1           2   36.0    118.0   8.0    72      5    2
# 2           3   12.0    149.0  12.6    74      5    3
# 3           4   18.0    313.0  11.5    62      5    4
# 4           5    NaN    238.0  14.3    56      5    5

# %%
print(air.head())
ozone_mean=air['Solar.R'].mean()
air['Solar.R'].fillna(ozone_mean,inplace=True)
print(air['Solar.R'].isnull().sum())
print(air.head())
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0           1   41.0    190.0   7.4    67      5    1
# 1           2   36.0    118.0   8.0    72      5    2
# 2           3   12.0    149.0  12.6    74      5    3
# 3           4   18.0    313.0  11.5    62      5    4
# 4           5    NaN    238.0  14.3    56      5    5
# 0
#    Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day
# 0           1   41.0    190.0   7.4    67      5    1
# 1           2   36.0    118.0   8.0    72      5    2
# 2           3   12.0    149.0  12.6    74      5    3
# 3           4   18.0    313.0  11.5    62      5    4
# 4           5    NaN    238.0  14.3    56      5    5

# %%
bins=[0,50,100,150,200,250,300,350]
labels=['0-50','50-100','100-150','150-200','200-250','250-300','300-350']
air['Solar.R.Interval']=pd.cut(air['Solar.R'],bins=bins,labels=labels,include_lowest=True)
print(air.head())
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day Solar.R.Interval
# 0           1   41.0    190.0   7.4    67      5    1          150-200
# 1           2   36.0    118.0   8.0    72      5    2          100-150
# 2           3   12.0    149.0  12.6    74      5    3          100-150
# 3           4   18.0    313.0  11.5    62      5    4          300-350
# 4           5    NaN    238.0  14.3    56      5    5          200-250

# %%
air['Solar>Danger']=air['Solar.R'].apply(lambda x:'yes' if x>150 else 'no')
print(air.head())
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind  Temp  Month  Day Solar.R.Interval  \
# 0           1   41.0    190.0   7.4    67      5    1          150-200
# 1           2   36.0    118.0   8.0    72      5    2          100-150
# 2           3   12.0    149.0  12.6    74      5    3          100-150
# 3           4   18.0    313.0  11.5    62      5    4          300-350
# 4           5    NaN    238.0  14.3    56      5    5          200-250
#
#   Solar>Danger
# 0          yes
# 1           no
# 2           no
# 3          yes
# 4          yes

# %%
month_mapping={5:'May',6:'June',7:'July'}
air['Month']=air['Month'].map(month_mapping)
print(air.head())
# Out:
#    Unnamed: 0  Ozone  Solar.R  Wind  Temp Month  Day Solar.R.Interval  \
# 0           1   41.0    190.0   7.4    67   NaN    1          150-200
# 1           2   36.0    118.0   8.0    72   NaN    2          100-150
# 2           3   12.0    149.0  12.6    74   NaN    3          100-150
# 3           4   18.0    313.0  11.5    62   NaN    4          300-350
# 4           5    NaN    238.0  14.3    56   NaN    5          200-250
#
#   Solar>Danger
# 0          yes
# 1           no
# 2           no
# 3          yes
# 4          yes

# %%
air_loop=air.copy()
for index,row in air_loop.iterrows():
  air_loop.at[index,'Month']=month_mapping.get(row['Month'],row['Month'])
print(air_loop)
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind  Temp Month  Day Solar.R.Interval  \
# 0             1   41.0    190.0   7.4    67   NaN    1          150-200
# 1             2   36.0    118.0   8.0    72   NaN    2          100-150
# 2             3   12.0    149.0  12.6    74   NaN    3          100-150
# 3             4   18.0    313.0  11.5    62   NaN    4          300-350
# 4             5    NaN    238.0  14.3    56   NaN    5          200-250
# ..          ...    ...      ...   ...   ...   ...  ...              ...
# 148         149   30.0    193.0   6.9    70   NaN   26          150-200
# 149         150    NaN    145.0  13.2    77   NaN   27          100-150
# 150         151   14.0    191.0  14.3    75   NaN   28          150-200
# 151         152   18.0    131.0   8.0    76   NaN   29          100-150
# 152         153   20.0    223.0  11.5    68   NaN   30          200-250
#
#     Solar>Danger
# 0            yes
# 1             no
# 2             no
# 3            yes
# 4            yes
# ..           ...
# 148          yes
# 149           no
# 150          yes
# 151           no
# 152          yes
#
# [153 rows x 9 columns]

# %%
air_no_dup=air.drop_duplicates()
print(air_no_dup.duplicated().sum())
print(len(air_no_dup))
# Out:
# 0
# 153

# %%
print(air.dtypes)
air['Wind']=air['Wind'].astype(int)
print(air.dtypes)
# Out:
# Unnamed: 0             int64
# Ozone                float64
# Solar.R              float64
# Wind                 float64
# Temp                   int64
# Month                 object
# Day                    int64
# Solar.R.Interval    category
# Solar>Danger          object
# dtype: object
# Unnamed: 0             int64
# Ozone                float64
# Solar.R              float64
# Wind                   int64
# Temp                   int64
# Month                 object
# Day                    int64
# Solar.R.Interval    category
# Solar>Danger          object
# dtype: object

# %%
from sklearn.preprocessing import MinMaxScaler
print(air[['Ozone','Solar.R']].head())
scaler=MinMaxScaler()
air[['Ozone','Solar.R']]=scaler.fit_transform(air[['Ozone','Solar.R']])
print(air[['Ozone','Solar.R']].head())
# Out:
#    Ozone  Solar.R
# 0   41.0    190.0
# 1   36.0    118.0
# 2   12.0    149.0
# 3   18.0    313.0
# 4    NaN    238.0
#       Ozone   Solar.R
# 0  0.239521  0.559633
# 1  0.209581  0.339450
# 2  0.065868  0.434251
# 3  0.101796  0.935780
# 4       NaN  0.706422

# %%
print(air['Month'].unique)
air['Month']=air['Month'].str.capitalize()
print(air['Month'].unique)
# Out:
# <bound method Series.unique of 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 148    NaN
# 149    NaN
# 150    NaN
# 151    NaN
# 152    NaN
# Name: Month, Length: 153, dtype: object>
# <bound method Series.unique of 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 148    NaN
# 149    NaN
# 150    NaN
# 151    NaN
# 152    NaN
# Name: Month, Length: 153, dtype: object>

# %%
air_cleaned=air.drop(['Month'],axis=1)
print(air_cleaned.columns)
# Out:
# Index(['Unnamed: 0', 'Ozone', 'Solar.R', 'Wind', 'Temp', 'Day',
#        'Solar.R.Interval', 'Solar>Danger'],
#       dtype='object')
