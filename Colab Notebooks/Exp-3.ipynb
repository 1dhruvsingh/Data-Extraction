# %%
import pandas as pd

# %%
df=pd.read_csv('customer_churn.csv')
print(df.head())
print(df.info())
print(df.describe())
# Out:
#                                                            customerID;gender;SeniorCitizen;Partner;Dependents;tenure;PhoneService;MultipleLines;InternetService;OnlineSecurity;OnlineBackup;DeviceProtection;TechSupport;StreamingTV;StreamingMovies;Contract;PaperlessBilling;PaymentMethod;MonthlyCharges;TotalCharges;Churn
# 7590-VHVEG;;;;;;;;;;;;;;;;;Electronic check;29     85;29                                                85;No
# 5575-GNVDE;;;;;;;;;;;;;;;;;Mailed check;56         95;1889                                               5;No
# 3668-QPYBK;;;;;;;;;;;;;;;;;Mailed check;53         85;108                                              15;Yes
# 7795-CFOCW;;;;;;;;;;;;;;;;;Bank transfer (autom... 3;1840                                               75;No
# 9237-HQITU;;;;;;;;;;;;;;;;;Electronic check;70     7;151                                               65;Yes
# <class 'pandas.core.frame.DataFrame'>
# ...

# %%
df_sorted=df.sort_values(by='gender',ascending=False)
print(df_sorted.head())
df_sorted=df.sort_values(by='gender',ascending=True)
print(df_sorted.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-137-0ac839269bf8> in <cell line: 1>()
# ----> 1 df_sorted=df.sort_values(by='gender',ascending=False)
#       2 print(df_sorted.head())
#       3 df_sorted=df.sort_values(by='gender',ascending=True)
#       4 print(df_sorted.head())
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6942             # len(by) == 1
#    6943
# -> 6944             k = self._get_label_or_level_values(by[0], axis=axis)
#    6945
#    6946             # need to rewrap column in Series to apply key function
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1842             values = self.axes[axis].get_level_values(key)._values
#    1843         else:
# ...

# %%
df['SeniorCitizen']=df['SeniorCitizen'].map({1:'Yes',0:'No'})
print(df[['SeniorCitizen']].head())

# %%
df['MonthlyChargePerYear']=df['MonthlyCharges']*df.tenure
print(df[['MonthlyCharges','MonthlyChargePerYear']].head())

# %%
df_subset=df[df['tenure']>24]
print(df_subset.head())
df_churned=df[df['Churn']=='yes']
print(df_churned.head())

# %%
df_agg=df.groupby('Contract').agg({'MonthlyCharges':'mean'})
print(df_agg)

# %%
df_agg_internet_service=df[df['Churn']=='Yes'].groupby('InternetService').size()
print(df_agg_internet_service)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b2031a12db88> in <cell line: 1>()
# ----> 1 df_agg_internet_service=df[df['Churn']=='Yes'].groupby('InternetService').size()
#       2 print(df_agg_internet_service)
#
# NameError: name 'df' is not defined

# %%
df.at[4,'MonthlyCharges']+=5
print(df.loc[4,'MonthlyCharges'])

# %%
df.at[6,'MonthlyCharges']-=9.65
print(df.loc[6,'MonthlyCharges'])

# %%
df.at[1,'MonthlyCharges']*3
print(df.loc[1,'MonthlyCharges'])

# %%
df.at[37,'MonthlyCharges']/3
print(df.loc[37,'MonthlyCharges'])

# %%
tenure_greater=df.at[2,'tenure']==df.at[4,'tenure']
print(tenure_greater)

# %%
both_services_count=df[(df['TechSupport']=='Yes')&(df['StreamingTV']=='Yes')].shape[1]
print(both_services_count)

# %%
func=df[(df['InternetService']=='DSL')&(df['InternetService']=='Fiber optic')].shape[0]
print(func)

# %%
senior_male_electronic=df[(df['SeniorCitizen']=='0')&(df['SeniorCitizen']=='1')].shape[0]
print(senior_male_electronic)

# %%
missing_values_count=df.isnull().sum()
print(missing_values_count)
# Out:
# customerID;gender;SeniorCitizen;Partner;Dependents;tenure;PhoneService;MultipleLines;InternetService;OnlineSecurity;OnlineBackup;DeviceProtection;TechSupport;StreamingTV;StreamingMovies;Contract;PaperlessBilling;PaymentMethod;MonthlyCharges;TotalCharges;Churn    679
# dtype: int64

# %%
dsl_tenure_above_45=df[(df['InternetService']=='DSL')&(df['tenure']>45)]
print(sl_tenure_above_45.head())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'InternetService'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-139-298caecdb2e4> in <cell line: 1>()
# ...

# %%
max_tenure=df['tenure'].max()
print(max_tenure)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tenure'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-138-24a6f1f7fd9d> in <cell line: 1>()
# ----> 1 max_tenure=df['tenure'].max()
#       2 print(max_tenure)
#
# ...
